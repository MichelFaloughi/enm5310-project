# %%
# !pip install zarr
# Out:
# ...
#    ---------------------------------------- 0.0/799.3 kB ? eta -:--:--
#    ---------------------------------------- 799.3/799.3 kB 7.4 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
#    ---------------------------------------- 0/4 [numcodecs]
# ...
